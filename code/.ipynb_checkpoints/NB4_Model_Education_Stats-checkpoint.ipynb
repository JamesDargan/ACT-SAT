# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import statsmodels.api as sm
from statsmodels.formula.api import ols

sns.set_style("whitegrid")

# %% [markdown]
# ## Data Import

# %%
test_scores = pd.read_csv('../data/test_scores_supplemented.csv', index_col='State')
naep_by_state = pd.read_csv('../data/naep_by_state.csv', index_col='State')

# %% [markdown]
# ## Relative Exam Rankings

# %%
test_ranks = naep_by_state[['naep_2017_math_rank']].copy()
test_ranks['sat_2017_math_rank'] = test_scores['sat_2017_math'].rank(ascending=False, method = 'min')
test_ranks['act_2017_math_rank'] = test_scores['act_2017_math'].rank(ascending=False, method = 'min')

test_ranks['naep_2017_reading_rank'] = naep_by_state['naep_2017_reading_rank'].copy()
test_ranks['sat_2017_erw_rank'] = test_scores['sat_2017_erw'].rank(ascending=False, method = 'min')
test_ranks['act_2017_reading_rank'] = test_scores['act_2017_reading'].rank(ascending=False, method = 'min')

# %%
test_ranks.loc[:,['naep_2017_math_rank', 'sat_2017_math_rank', 'act_2017_math_rank',
                  'naep_2017_reading_rank', 'sat_2017_erw_rank', 'act_2017_reading_rank']
              ].sort_values('naep_2017_math_rank')
# Out:
#                       naep_2017_math_rank  sat_2017_math_rank  \
# State
# Massachusetts                         1.0                24.0
# Minnesota                             2.0                 1.0
# New Hampshire                         3.0                41.0
# New Jersey                            4.0                35.0
# Virginia                              5.0                27.0
# Wyoming                               6.0                11.0
# Washington                            6.0                30.0
# Ohio                                  8.0                19.0
# Wisconsin                             8.0                 2.0
# Vermont                               8.0                24.0
# North Dakota                          8.0                 7.0
# Nebraska                              8.0                 6.0
# Indiana                               8.0                32.0
# Utah                                 14.0                 9.0
# Iowa                                 15.0                 3.0
# Colorado                             15.0                14.0
# Pennsylvania                         15.0                33.0
# South Dakota                         15.0                13.0
# Montana                              15.0                16.0
# Kansas                               20.0                 5.0
# Maine                                21.0                46.0
# Idaho                                21.0                49.0
# Connecticut                          21.0                44.0
# Illinois                             24.0                21.0
# Oregon                               24.0                26.0
# North Carolina                       24.0                29.0
# New York                             24.0                39.0
# Arizona                              24.0                22.0
# Texas                                24.0                45.0
# Missouri                             30.0                 4.0
# Maryland                             30.0                36.0
# Georgia                              30.0                43.0
# Michigan                             33.0                48.0
# Florida                              34.0                47.0
# Tennessee                            34.0                11.0
# Kentucky                             36.0                 8.0
# Delaware                             36.0                50.0
# Alaska                               38.0                31.0
# Hawaii                               38.0                27.0
# Rhode Island                         38.0                36.0
# California                           38.0                36.0
# South Carolina                       42.0                40.0
# Oklahoma                             42.0                42.0
# Nevada                               42.0                22.0
# Arkansas                             45.0                15.0
# West Virginia                        46.0                34.0
# Mississippi                          47.0                10.0
# New Mexico                           48.0                20.0
# Alabama                              49.0                18.0
# Louisiana                            50.0                17.0
# District of Columbia                 51.0                 NaN
#
#                       act_2017_math_rank  naep_2017_reading_rank  \
# State
# Massachusetts                        1.0                     1.0
# Minnesota                           16.0                    11.0
# New Hampshire                        1.0                     2.0
# New Jersey                           6.0                     2.0
# Virginia                             6.0                    17.0
# Wyoming                             32.0                    11.0
# Washington                          16.0                     6.0
# Ohio                                16.0                    17.0
# Wisconsin                           25.0                    11.0
# Vermont                              6.0                     4.0
# North Dakota                        25.0                    30.0
# Nebraska                            25.0                    11.0
# Indiana                             14.0                     6.0
# Utah                                32.0                    11.0
# Iowa                                16.0                    17.0
# Colorado                            25.0                     8.0
# Pennsylvania                         6.0                     8.0
# South Dakota                        16.0                    20.0
# Montana                             25.0                    20.0
# Kansas                              16.0                    20.0
# Maine                                3.0                    11.0
# Idaho                               16.0                     8.0
# Connecticut                          3.0                     4.0
# Illinois                            16.0                    20.0
# Oregon                              16.0                    26.0
# North Carolina                      32.0                    34.0
# New York                             3.0                    33.0
# Arizona                             32.0                    34.0
# Texas                               25.0                    41.0
# Missouri                            32.0                    26.0
# Maryland                             6.0                    20.0
# Georgia                             25.0                    26.0
# Michigan                             6.0                    30.0
# Florida                             32.0                    20.0
# Tennessee                           32.0                    38.0
# Kentucky                            32.0                    30.0
# Delaware                             6.0                    34.0
# Alaska                              32.0                    46.0
# Hawaii                              32.0                    39.0
# Rhode Island                         6.0                    26.0
# California                          14.0                    34.0
# South Carolina                      45.0                    41.0
# Oklahoma                            45.0                    39.0
# Nevada                              45.0                    41.0
# Arkansas                            32.0                    41.0
# West Virginia                       32.0                    45.0
# Mississippi                         45.0                    49.0
# New Mexico                          32.0                    49.0
# Alabama                             45.0                    46.0
# Louisiana                           45.0                    48.0
# District of Columbia                 NaN                    51.0
#
#                       sat_2017_erw_rank  act_2017_reading_rank
# State
# Massachusetts                      28.0                    2.0
# Minnesota                           1.0                   24.0
# New Hampshire                      39.0                    1.0
# New Jersey                         41.0                    4.0
# Virginia                           24.0                    4.0
# Wyoming                            10.0                   32.0
# Washington                         34.0                   17.0
# Ohio                               19.0                   17.0
# Wisconsin                           2.0                   32.0
# Vermont                            23.0                    4.0
# North Dakota                        5.0                   32.0
# Nebraska                            9.0                   24.0
# Indiana                            33.0                   14.0
# Utah                               11.0                   32.0
# Iowa                                3.0                   17.0
# Colorado                           16.0                   24.0
# Pennsylvania                       35.0                    4.0
# South Dakota                       14.0                   17.0
# Montana                            17.0                   24.0
# Kansas                              7.0                   17.0
# Maine                              46.0                    4.0
# Idaho                              46.0                   14.0
# Connecticut                        41.0                    2.0
# Illinois                           26.0                   24.0
# Oregon                             25.0                   17.0
# North Carolina                     30.0                   43.0
# New York                           44.0                    4.0
# Arizona                            21.0                   32.0
# Texas                              46.0                   24.0
# Missouri                            4.0                   32.0
# Maryland                           37.0                    4.0
# Georgia                            38.0                   17.0
# Michigan                           49.0                    4.0
# Florida                            45.0                   24.0
# Tennessee                          12.0                   32.0
# Kentucky                            8.0                   32.0
# Delaware                           50.0                    4.0
# Alaska                             29.0                   32.0
# Hawaii                             31.0                   43.0
# Rhode Island                       36.0                    4.0
# California                         40.0                   14.0
# South Carolina                     32.0                   43.0
# Oklahoma                           41.0                   32.0
# Nevada                             21.0                   49.0
# Arkansas                           13.0                   43.0
# West Virginia                      27.0                   24.0
# Mississippi                         6.0                   49.0
# New Mexico                         20.0                   32.0
# Alabama                            18.0                   43.0
# Louisiana                          15.0                   43.0
# District of Columbia                NaN                    NaN

# %% [markdown]
# ## EDA State Statistics

# %%
plt.figure(figsize = (15,6))

ax1 = plt.subplot(131)
plt.hist(test_scores['pupil_teacher_ratio'], bins=10)
plt.xlabel('Student to Teacher Ratio', fontsize=12)
plt.ylabel('State Count', fontsize=12)


ax1 = plt.subplot(132)
plt.hist(test_scores['spending_per_student'], bins=10)
plt.xlabel('Spending per Student', fontsize=12)


ax3 = plt.subplot(133)
plt.hist(test_scores['teacher_salary'], bins=10)
plt.xlabel('Average Teacher Salary', fontsize=12)

plt.suptitle('State Stats are Skewed Right', fontsize=16)
;
# Out:
# ''

# %%
plt.figure(figsize = (15,6))

ax1 = plt.subplot(131)
plt.hist(np.log(test_scores['pupil_teacher_ratio']), bins=10)
plt.xlabel('Student to Teacher Ratio', fontsize=12)
plt.ylabel('State Count', fontsize=12)


ax1 = plt.subplot(132)
plt.hist(np.log(test_scores['spending_per_student']), bins=10)
plt.xlabel('Spending per Student', fontsize=12)


ax3 = plt.subplot(133)
plt.hist(np.log(test_scores['teacher_salary']), bins=10)
plt.xlabel('Average Teacher Salary', fontsize=12)

plt.suptitle('Log Transform does not Improve', fontsize=16)
;
# Out:
# ''

# %%
plt.figure(figsize = (16,12))

ax1 = plt.subplot(321)
sns.regplot(x='pupil_teacher_ratio', y='sat_2018', data=test_scores)

plt.xlabel("State Pupil to Teacher Ratio", fontsize = 16)
plt.ylabel("Average SAT Score", fontsize = 16)
plt.grid(True, linewidth=0.5, linestyle = '-', c='black', alpha = 0.15)


ax2 = plt.subplot(322)
sns.regplot(x='pupil_teacher_ratio', y='act_2018', data=test_scores)

plt.xlabel("State Pupil to Teacher Ratio", fontsize = 16)
plt.ylabel("Average ACT Score", fontsize = 16)
plt.grid(True, linewidth=0.5, linestyle = '-', c='black', alpha = 0.15)


ax3 = plt.subplot(323, sharey=ax1)
sns.regplot(x='spending_per_student', y='sat_2018', data=test_scores)

plt.xlabel("State Spending per Pupil", fontsize = 16)
plt.ylabel("Average SAT Score", fontsize = 16)
plt.grid(True, linewidth=0.5, linestyle = '-', c='black', alpha = 0.15)


ax4 = plt.subplot(324, sharey=ax2)
sns.regplot(x='spending_per_student', y='act_2018', data=test_scores)

plt.xlabel("State Spending per Pupil", fontsize = 16)
plt.ylabel("Average ACT Score", fontsize = 16)
plt.grid(True, linewidth=0.5, linestyle = '-', c='black', alpha = 0.15)


ax5 = plt.subplot(325, sharey=ax1)
sns.regplot(x='teacher_salary', y='sat_2018', data=test_scores)

plt.xlabel("Average Teacher Salary", fontsize = 16)
plt.ylabel("Average SAT Score", fontsize = 16)
plt.grid(True, linewidth=0.5, linestyle = '-', c='black', alpha = 0.15)


ax6 = plt.subplot(326, sharey=ax2)
sns.regplot(x='teacher_salary', y='act_2018', data=test_scores)

plt.xlabel("Average Teacher Salary", fontsize = 16)
plt.ylabel("Average ACT Score", fontsize = 16)
plt.grid(True, linewidth=0.5, linestyle = '-', c='black', alpha = 0.15)


plt.suptitle("Contrasting Relationships by Test ", fontsize = 20)
;
# Out:
# ''

# %% [markdown]
# Above we note that these state statistics do not have a very strong relationship with test score state averages on their own. Importantly, we note the sign of the relationship flips between SAT and ACT for 2 of the 3 features.

# %%
test_scores['sat_2018_part50'] = 0
test_scores.loc[test_scores['sat_2018_part'] >= 50, 'sat_2018_part50'] = 1
test_scores['act_2018_part50'] = 0
test_scores.loc[test_scores['act_2018_part'] >= 50, 'act_2018_part50'] = 1

# %%
plt.figure(figsize = (16,12))

ax1 = plt.subplot(321)
sns.scatterplot(x='pupil_teacher_ratio', y='sat_2018', hue='sat_2018_part50', data=test_scores)

plt.xlabel("State Pupil to Teacher Ratio", fontsize = 16)
plt.ylabel("Average SAT Score", fontsize = 16)
plt.grid(True, linewidth=0.5, linestyle = '-', c='black', alpha = 0.15)
ax1.get_legend().remove()


ax2 = plt.subplot(322)
sns.scatterplot(x='pupil_teacher_ratio', y='act_2018', hue='act_2018_part50', data=test_scores)

plt.xlabel("State Pupil to Teacher Ratio", fontsize = 16)
plt.ylabel("Average ACT Score", fontsize = 16)
plt.grid(True, linewidth=0.5, linestyle = '-', c='black', alpha = 0.15)
ax2.get_legend().remove()


ax3 = plt.subplot(323, sharey=ax1)
sns.scatterplot(x='spending_per_student', y='sat_2018', hue='sat_2018_part50', data=test_scores)

plt.xlabel("State Spending per Pupil", fontsize = 16)
plt.ylabel("Average SAT Score", fontsize = 16)
plt.grid(True, linewidth=0.5, linestyle = '-', c='black', alpha = 0.15)
ax3.get_legend().remove()


ax4 = plt.subplot(324, sharey=ax2)
sns.scatterplot(x='spending_per_student', y='act_2018', hue='act_2018_part50', data=test_scores)

plt.xlabel("State Spending per Pupil", fontsize = 16)
plt.ylabel("Average ACT Score", fontsize = 16)
plt.grid(True, linewidth=0.5, linestyle = '-', c='black', alpha = 0.15)
ax4.get_legend().remove()


ax5 = plt.subplot(325, sharey=ax1)
sns.scatterplot(x='teacher_salary', y='sat_2018', hue='sat_2018_part50', data=test_scores)

plt.xlabel("Average Teacher Salary", fontsize = 16)
plt.ylabel("Average SAT Score", fontsize = 16)
plt.grid(True, linewidth=0.5, linestyle = '-', c='black', alpha = 0.15)
ax5.get_legend().remove()


ax6 = plt.subplot(326, sharey=ax2)
sns.scatterplot(x='teacher_salary', y='act_2018', hue='act_2018_part50', data=test_scores)

plt.xlabel("Average Teacher Salary", fontsize = 16)
plt.ylabel("Average ACT Score", fontsize = 16)
plt.grid(True, linewidth=0.5, linestyle = '-', c='black', alpha = 0.15)
ax6.get_legend().remove()

plt.suptitle("Greater Participation Drives Down Averages \n Orange > 50% Participation", fontsize = 20)
;
# Out:
# ''

# %% [markdown]
# By color-coding for state participation rate, we find the diverging relationships identified in the previous plots were driven more by participation rates than the depicted value. High and low participation-rate states differ systematically in their scores which conflates the estimate of state education system statistics.

# %% [markdown]
# ## State Statistics Correlation
#
# We observe significant correlation between our state features, suggesting any coefficients cannot be meaningfully interpreted in a multiple linear regression model.

# %%
# Convert to Thousands for Interpretability
test_scores['spending_per_student'] = test_scores['spending_per_student']/1000
test_scores['teacher_salary'] = test_scores['teacher_salary']/1000

# Correlations
test_scores[['sat_2018_part','pupil_teacher_ratio', 'spending_per_student', 'teacher_salary']].corr()
# Out:
#                       sat_2018_part  pupil_teacher_ratio  \
# sat_2018_part              1.000000            -0.062846
# pupil_teacher_ratio       -0.062846             1.000000
# spending_per_student       0.413286            -0.538331
# teacher_salary             0.497672            -0.032984
#
#                       spending_per_student  teacher_salary
# sat_2018_part                     0.413286        0.497672
# pupil_teacher_ratio              -0.538331       -0.032984
# spending_per_student              1.000000        0.754388
# teacher_salary                    0.754388        1.000000

# %% [markdown]
# ## Regression with State Statistics
#
# Below we create several basic linear regression models utilizing one state statistic and then adding participation rate. Generally, state statistics have a statistically insignificant coefficient and extremely low explanatory power. When added to models incorporating state participation rates, we find marginal gains in explanatory power compared to the previous univariate models, however many coefficients remain insignificant. Importantly, we find these coefficients vary greatly between using SAT and ACT averages as our dependent / target variable.

# %% [markdown]
# #### SAT

# %%
sat_coef=dict()
sat_p = dict()

# %%
X = test_scores[['spending_per_student']]
X = sm.add_constant(X)
y = test_scores['sat_2018']

lr_model = sm.OLS(y, X)
lr_sat_2018 = lr_model.fit()

sat_coef['spend'] =lr_sat_2018.params
sat_p['spend'] = lr_sat_2018.pvalues

print(lr_sat_2018.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               sat_2018   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     1.701
# Date:                Tue, 16 Jun 2020   Prob (F-statistic):              0.198
# Time:                        17:40:30   Log-Likelihood:                -295.88
# No. Observations:                  50   AIC:                             595.8
# Df Residuals:                      48   BIC:                             599.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 1186.9764     47.322     25.083      0.000    1091.828    1282.125
# spending_per_student    -4.4531      3.414     -1.304      0.198     -11.318       2.412
# ==============================================================================
# Omnibus:                        6.323   Durbin-Watson:                   1.410
# Prob(Omnibus):                  0.042   Jarque-Bera (JB):                2.938
# Skew:                           0.321   Prob(JB):                        0.230
# Kurtosis:                       2.001   Cond. No.                         50.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X = test_scores[['spending_per_student', 'sat_2018_part']]
X = sm.add_constant(X)
y = test_scores['sat_2018']

lr_model = sm.OLS(y, X)
lr_sat_2018 = lr_model.fit()

sat_coef['spend_part'] =lr_sat_2018.params
sat_p['spend_part'] = lr_sat_2018.pvalues

print(lr_sat_2018.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               sat_2018   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.737
# Method:                 Least Squares   F-statistic:                     69.78
# Date:                Tue, 16 Jun 2020   Prob (F-statistic):           8.51e-15
# Time:                        17:40:30   Log-Likelihood:                -262.28
# No. Observations:                  50   AIC:                             530.6
# Df Residuals:                      47   BIC:                             536.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 1167.5359     24.483     47.687      0.000    1118.282    1216.790
# spending_per_student     4.7769      1.935      2.468      0.017       0.884       8.670
# sat_2018_part           -2.2657      0.196    -11.540      0.000      -2.661      -1.871
# ==============================================================================
# Omnibus:                       20.731   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.609
# Skew:                          -1.375   Prob(JB):                     2.26e-07
# Kurtosis:                       5.671   Cond. No.                         221.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X = test_scores[['teacher_salary']]
X = sm.add_constant(X)
y = test_scores['sat_2018']

lr_model = sm.OLS(y, X)
lr_sat_2018 = lr_model.fit()

sat_coef['sal'] =lr_sat_2018.params
sat_p['sal'] = lr_sat_2018.pvalues

print(lr_sat_2018.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               sat_2018   R-squared:                       0.098
# Model:                            OLS   Adj. R-squared:                  0.080
# Method:                 Least Squares   F-statistic:                     5.235
# Date:                Tue, 16 Jun 2020   Prob (F-statistic):             0.0266
# Time:                        17:40:30   Log-Likelihood:                -294.16
# No. Observations:                  50   AIC:                             592.3
# Df Residuals:                      48   BIC:                             596.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1299.4908     76.160     17.063      0.000    1146.361    1452.620
# teacher_salary    -2.9561      1.292     -2.288      0.027      -5.554      -0.358
# ==============================================================================
# Omnibus:                        4.231   Durbin-Watson:                   1.667
# Prob(Omnibus):                  0.121   Jarque-Bera (JB):                1.908
# Skew:                           0.087   Prob(JB):                        0.385
# Kurtosis:                       2.059   Cond. No.                         358.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X = test_scores[['teacher_salary', 'sat_2018_part']]
X = sm.add_constant(X)
y = test_scores['sat_2018']

lr_model = sm.OLS(y, X)
lr_sat_2018 = lr_model.fit()

sat_coef['sal_part'] = lr_sat_2018.params
sat_p['sal_part'] = lr_sat_2018.pvalues

print(lr_sat_2018.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               sat_2018   R-squared:                       0.731
# Model:                            OLS   Adj. R-squared:                  0.719
# Method:                 Least Squares   F-statistic:                     63.77
# Date:                Tue, 16 Jun 2020   Prob (F-statistic):           4.07e-14
# Time:                        17:40:30   Log-Likelihood:                -263.95
# No. Observations:                  50   AIC:                             533.9
# Df Residuals:                      47   BIC:                             539.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1151.7614     44.348     25.971      0.000    1062.545    1240.978
# teacher_salary     1.3453      0.823      1.635      0.109      -0.310       3.000
# sat_2018_part     -2.2388      0.213    -10.506      0.000      -2.668      -1.810
# ==============================================================================
# Omnibus:                       16.037   Durbin-Watson:                   1.798
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.551
# Skew:                          -1.181   Prob(JB):                     5.68e-05
# Kurtosis:                       4.951   Cond. No.                         509.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X = test_scores[['spending_per_student', 'teacher_salary']]
X = sm.add_constant(X)
y = test_scores['sat_2018']

lr_model = sm.OLS(y, X)
lr_sat_2018 = lr_model.fit()

print(lr_sat_2018.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               sat_2018   R-squared:                       0.104
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     2.742
# Date:                Tue, 16 Jun 2020   Prob (F-statistic):             0.0747
# Time:                        17:40:30   Log-Likelihood:                -293.99
# No. Observations:                  50   AIC:                             594.0
# Df Residuals:                      47   BIC:                             599.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 1310.5747     79.137     16.561      0.000    1151.371    1469.779
# spending_per_student     2.8797      5.061      0.569      0.572      -7.303      13.062
# teacher_salary          -3.8069      1.982     -1.920      0.061      -7.795       0.181
# ==============================================================================
# Omnibus:                        4.607   Durbin-Watson:                   1.691
# Prob(Omnibus):                  0.100   Jarque-Bera (JB):                1.961
# Skew:                           0.054   Prob(JB):                        0.375
# Kurtosis:                       2.036   Cond. No.                         379.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X = test_scores[['spending_per_student', 'teacher_salary', 'sat_2018_part']]
X = sm.add_constant(X)
y = test_scores['sat_2018']

lr_model = sm.OLS(y, X)
lr_sat_2018 = lr_model.fit()

sat_coef['spend_sal_part'] =lr_sat_2018.params
sat_p['spend_sal_part'] = lr_sat_2018.pvalues

print(lr_sat_2018.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               sat_2018   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.732
# Method:                 Least Squares   F-statistic:                     45.53
# Date:                Tue, 16 Jun 2020   Prob (F-statistic):           8.12e-14
# Time:                        17:40:30   Log-Likelihood:                -262.28
# No. Observations:                  50   AIC:                             532.6
# Df Residuals:                      46   BIC:                             540.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 1168.7586     44.399     26.324      0.000    1079.387    1258.130
# spending_per_student     4.8395      2.720      1.779      0.082      -0.635      10.314
# teacher_salary          -0.0371      1.118     -0.033      0.974      -2.288       2.214
# sat_2018_part           -2.2635      0.209    -10.840      0.000      -2.684      -1.843
# ==============================================================================
# Omnibus:                       20.832   Durbin-Watson:                   1.889
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.900
# Skew:                          -1.378   Prob(JB):                     1.95e-07
# Kurtosis:                       5.689   Cond. No.                         529.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sat_coef_df = round(pd.DataFrame.from_dict(sat_coef),2)
sat_p_df = round(pd.DataFrame.from_dict(sat_p),4)
sat_df = pd.merge(sat_coef_df, sat_p_df, left_index=True, right_index=True)
sat_df.columns = ['I','II','III','IV','V', 'I(p)','II(p)','III(p)','IV(p)','V(p)']
sat_df = sat_df[sat_df.columns.sort_values()]
sat_df
# Out:
#                             I    I(p)       II   II(p)      III  III(p)  \
# const                 1186.98  0.0000  1167.54  0.0000  1299.49  0.0000
# sat_2018_part             NaN     NaN    -2.27  0.0000      NaN     NaN
# spending_per_student    -4.45  0.1984     4.78  0.0173      NaN     NaN
# teacher_salary            NaN     NaN      NaN     NaN    -2.96  0.0266
#
#                            IV   IV(p)        V    V(p)
# const                 1151.76  0.0000  1168.76  0.0000
# sat_2018_part           -2.24  0.0000    -2.26  0.0000
# spending_per_student      NaN     NaN     4.84  0.0818
# teacher_salary           1.35  0.1087    -0.04  0.9737

# %% [markdown]
# #### ACT

# %%
act_coef=dict()
act_p = dict()

# %%
X = test_scores[['spending_per_student']]
X = sm.add_constant(X)
y = test_scores['act_2018']

lr_model = sm.OLS(y, X)
lr_act_2018 = lr_model.fit()

act_coef['spend'] =lr_act_2018.params
act_p['spend'] = lr_act_2018.pvalues

print(lr_act_2018.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               act_2018   R-squared:                       0.408
# Model:                            OLS   Adj. R-squared:                  0.396
# Method:                 Least Squares   F-statistic:                     33.11
# Date:                Tue, 16 Jun 2020   Prob (F-statistic):           5.95e-07
# Time:                        17:40:30   Log-Likelihood:                -94.063
# No. Observations:                  50   AIC:                             192.1
# Df Residuals:                      48   BIC:                             195.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   16.3949      0.836     19.614      0.000      14.714      18.076
# spending_per_student     0.3470      0.060      5.754      0.000       0.226       0.468
# ==============================================================================
# Omnibus:                        0.019   Durbin-Watson:                   1.843
# Prob(Omnibus):                  0.991   Jarque-Bera (JB):                0.188
# Skew:                          -0.008   Prob(JB):                        0.910
# Kurtosis:                       2.700   Cond. No.                         50.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X = test_scores[['spending_per_student', 'act_2018_part']]
X = sm.add_constant(X)
y = test_scores['act_2018']

lr_model = sm.OLS(y, X)
lr_act_2018 = lr_model.fit()

act_coef['spend_part'] =lr_act_2018.params
act_p['spend_part'] = lr_act_2018.pvalues

print(lr_act_2018.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               act_2018   R-squared:                       0.765
# Model:                            OLS   Adj. R-squared:                  0.755
# Method:                 Least Squares   F-statistic:                     76.48
# Date:                Tue, 16 Jun 2020   Prob (F-statistic):           1.67e-15
# Time:                        17:40:30   Log-Likelihood:                -70.977
# No. Observations:                  50   AIC:                             148.0
# Df Residuals:                      47   BIC:                             153.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   21.6070      0.815     26.512      0.000      19.968      23.247
# spending_per_student     0.1540      0.045      3.446      0.001       0.064       0.244
# act_2018_part           -0.0424      0.005     -8.446      0.000      -0.053      -0.032
# ==============================================================================
# Omnibus:                        7.275   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.026   Jarque-Bera (JB):                6.227
# Skew:                          -0.773   Prob(JB):                       0.0444
# Kurtosis:                       3.775   Cond. No.                         401.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X = test_scores[['teacher_salary']]
X = sm.add_constant(X)
y = test_scores['act_2018']

lr_model = sm.OLS(y, X)
lr_act_2018 = lr_model.fit()

act_coef['sal'] =lr_act_2018.params
act_p['sal'] = lr_act_2018.pvalues

print(lr_act_2018.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               act_2018   R-squared:                       0.384
# Model:                            OLS   Adj. R-squared:                  0.371
# Method:                 Least Squares   F-statistic:                     29.88
# Date:                Tue, 16 Jun 2020   Prob (F-statistic):           1.62e-06
# Time:                        17:40:30   Log-Likelihood:                -95.079
# No. Observations:                  50   AIC:                             194.2
# Df Residuals:                      48   BIC:                             198.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             13.3600      1.421      9.403      0.000      10.503      16.217
# teacher_salary     0.1317      0.024      5.466      0.000       0.083       0.180
# ==============================================================================
# Omnibus:                        1.210   Durbin-Watson:                   2.098
# Prob(Omnibus):                  0.546   Jarque-Bera (JB):                0.996
# Skew:                           0.341   Prob(JB):                        0.608
# Kurtosis:                       2.886   Cond. No.                         358.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X = test_scores[['teacher_salary', 'act_2018_part']]
X = sm.add_constant(X)
y = test_scores['act_2018']

lr_model = sm.OLS(y, X)
lr_act_2018 = lr_model.fit()

act_coef['sal_part'] =lr_act_2018.params
act_p['sal_part'] = lr_act_2018.pvalues

print(lr_act_2018.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               act_2018   R-squared:                       0.728
# Model:                            OLS   Adj. R-squared:                  0.717
# Method:                 Least Squares   F-statistic:                     62.94
# Date:                Tue, 16 Jun 2020   Prob (F-statistic):           5.10e-14
# Time:                        17:40:30   Log-Likelihood:                -74.616
# No. Observations:                  50   AIC:                             155.2
# Df Residuals:                      47   BIC:                             161.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             21.4815      1.420     15.126      0.000      18.624      24.339
# teacher_salary     0.0397      0.020      1.975      0.054      -0.001       0.080
# act_2018_part     -0.0445      0.006     -7.717      0.000      -0.056      -0.033
# ==============================================================================
# Omnibus:                        3.149   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.207   Jarque-Bera (JB):                3.009
# Skew:                          -0.571   Prob(JB):                        0.222
# Kurtosis:                       2.625   Cond. No.                         797.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X = test_scores[['spending_per_student', 'teacher_salary']]
X = sm.add_constant(X)
y = test_scores['act_2018']

lr_model = sm.OLS(y, X)
lr_act_2018 = lr_model.fit()
print(lr_act_2018.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               act_2018   R-squared:                       0.452
# Model:                            OLS   Adj. R-squared:                  0.429
# Method:                 Least Squares   F-statistic:                     19.38
# Date:                Tue, 16 Jun 2020   Prob (F-statistic):           7.27e-07
# Time:                        17:40:30   Log-Likelihood:                -92.140
# No. Observations:                  50   AIC:                             190.3
# Df Residuals:                      47   BIC:                             196.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   14.1927      1.397     10.160      0.000      11.383      17.003
# spending_per_student     0.2163      0.089      2.421      0.019       0.037       0.396
# teacher_salary           0.0678      0.035      1.939      0.059      -0.003       0.138
# ==============================================================================
# Omnibus:                        0.346   Durbin-Watson:                   2.067
# Prob(Omnibus):                  0.841   Jarque-Bera (JB):                0.139
# Skew:                           0.129   Prob(JB):                        0.933
# Kurtosis:                       2.997   Cond. No.                         379.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X = test_scores[['spending_per_student', 'teacher_salary', 'act_2018_part']]
X = sm.add_constant(X)
y = test_scores['act_2018']

lr_model = sm.OLS(y, X)
lr_act_2018 = lr_model.fit()

act_coef['spend_sal_part'] =lr_act_2018.params
act_p['spend_sal_part'] = lr_act_2018.pvalues

print(lr_act_2018.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               act_2018   R-squared:                       0.765
# Model:                            OLS   Adj. R-squared:                  0.750
# Method:                 Least Squares   F-statistic:                     49.94
# Date:                Tue, 16 Jun 2020   Prob (F-statistic):           1.64e-14
# Time:                        17:40:30   Log-Likelihood:                -70.963
# No. Observations:                  50   AIC:                             149.9
# Df Residuals:                      46   BIC:                             157.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   21.7758      1.339     16.264      0.000      19.081      24.471
# spending_per_student     0.1602      0.060      2.690      0.010       0.040       0.280
# teacher_salary          -0.0040      0.025     -0.160      0.874      -0.054       0.046
# act_2018_part           -0.0427      0.005     -7.830      0.000      -0.054      -0.032
# ==============================================================================
# Omnibus:                        7.240   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.027   Jarque-Bera (JB):                6.188
# Skew:                          -0.767   Prob(JB):                       0.0453
# Kurtosis:                       3.787   Cond. No.                         808.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
act_coef_df = round(pd.DataFrame.from_dict(act_coef),2)
act_p_df = round(pd.DataFrame.from_dict(act_p),4)
act_df = pd.merge(act_coef_df, act_p_df, left_index=True, right_index=True)
act_df.columns = ['I','II','III','IV','V', 'I(p)','II(p)','III(p)','IV(p)','V(p)']
act_df = act_df[act_df.columns.sort_values()]
act_df
# Out:
#                           I  I(p)     II   II(p)    III  III(p)     IV  \
# act_2018_part           NaN   NaN  -0.04  0.0000    NaN     NaN  -0.04
# const                 16.39   0.0  21.61  0.0000  13.36     0.0  21.48
# spending_per_student   0.35   0.0   0.15  0.0012    NaN     NaN    NaN
# teacher_salary          NaN   NaN    NaN     NaN   0.13     0.0   0.04
#
#                        IV(p)      V    V(p)
# act_2018_part         0.0000  -0.04  0.0000
# const                 0.0000  21.78  0.0000
# spending_per_student     NaN   0.16  0.0099
# teacher_salary        0.0541  -0.00  0.8737

# %% [markdown]
# ## Summary

# %%
sat_df.reindex(index = ['const','sat_2018_part','spending_per_student','teacher_salary'])
# Out:
#                             I    I(p)       II   II(p)      III  III(p)  \
# const                 1186.98  0.0000  1167.54  0.0000  1299.49  0.0000
# sat_2018_part             NaN     NaN    -2.27  0.0000      NaN     NaN
# spending_per_student    -4.45  0.1984     4.78  0.0173      NaN     NaN
# teacher_salary            NaN     NaN      NaN     NaN    -2.96  0.0266
#
#                            IV   IV(p)        V    V(p)
# const                 1151.76  0.0000  1168.76  0.0000
# sat_2018_part           -2.24  0.0000    -2.26  0.0000
# spending_per_student      NaN     NaN     4.84  0.0818
# teacher_salary           1.35  0.1087    -0.04  0.9737

# %%
act_df.reindex(index = ['const','act_2018_part','spending_per_student','teacher_salary'])
# Out:
#                           I  I(p)     II   II(p)    III  III(p)     IV  \
# const                 16.39   0.0  21.61  0.0000  13.36     0.0  21.48
# act_2018_part           NaN   NaN  -0.04  0.0000    NaN     NaN  -0.04
# spending_per_student   0.35   0.0   0.15  0.0012    NaN     NaN    NaN
# teacher_salary          NaN   NaN    NaN     NaN   0.13     0.0   0.04
#
#                        IV(p)      V    V(p)
# const                 0.0000  21.78  0.0000
# act_2018_part         0.0000  -0.04  0.0000
# spending_per_student     NaN   0.16  0.0099
# teacher_salary        0.0541  -0.00  0.8737

# %% [markdown]
# In all of our models, the participation rate variable dominated all others in impact. The explanatory models of all models without participation rates were low, although they were much more powerful in explaining ACT than SAT averages. Above we noted how participation rates appeared to distort the appearance of relationships between state test averages and underlying system statistics. Here we find that the coefficients for these variables reduces drastically once we control for participation rate. Furthermore, we find the signs of these education indicators flips based on whether SAT or ACT scores serve as the target variable.
